# %%
# Cell 0  ──────────────────────────────────────────────────────────────
import numpy as np
import pandas as pd
import torch
import dgl

# 👇 import the encoder implementation that came with SpaFormer
#    (see modules in the spaformer package)
import pathlib, sys
from spaformer import build_model
from types import SimpleNamespace

# ensure the spaformer package resolves when the notebook runs
PROJECT_ROOT = pathlib.Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))


# --- convenience wrapper --------------------------------------------------
def build_graph(edge_index, num_nodes):
    """
    edge_index: np.ndarray with shape (2, E) – COO (src, dst)
    returns    : DGLGraph on CPU
    """
    g = dgl.graph((edge_index[0], edge_index[1]), num_nodes=num_nodes)
    g = dgl.add_self_loop(g)          # SpaFormer expects self-loops
    return g

# %%
# Cell 1  ──────────────────────────────────────────────────────────────
# paths
PP_DIR = pathlib.Path("Data/spaformer_prepared")

# ① expression matrix  (cells × genes)        float32
X_np     = np.load(PP_DIR / "X.npy")          # (N, G)
# ② spatial coordinates (cells × 2, 0-1 norm) float32
C_np     = np.load(PP_DIR / "C.npy")          # (N, 2)
# ③ graph (2 × E) int32  – already K-NN, undirected, COO
edges_np = np.load(PP_DIR / "edges.npy")      # (2, E)

N, G = X_np.shape
print(f"cells: {N}   genes: {G}   edges: {edges_np.shape[1]}")
# Out:
# cells: 3639   genes: 3003   edges: 21834

# %%
# Configuration (nested learning + clustering)
enable_nested_learning = True
cluster_method = 'kmeans'  # 'leiden' | 'kmeans' | 'dbscan' (kmeans enforces fixed K)
outer_iters = 20
outer_epochs_per_iter = 3
knn_k = 15
leiden_resolution = 0.6
kmeans_K = 7  # target cluster count
dbscan_eps = 0.8
dbscan_min_samples = 3

lambda_mask = 1.0
lambda_cluster = 1.0
lambda_smooth = 0.1
lambda_cons = 0.1

smoothness_mode = 'embedding'  # 'embedding' or 'kl_logits'
device = 'auto'  # 'auto', 'cpu', or 'cuda'

random_seed = 42

# %%
# Cell 2  ──────────────────────────────────────────────────────────────
# torch tensors on CPU
X_t = torch.from_numpy(X_np)        # (N, G)
C_t = torch.from_numpy(C_np)        # (N, 2)

# DGL graph
g = build_graph(edges_np, N)

print(g)          # sanity check
print("X_t", X_t.shape, X_t.dtype)
print("C_t", C_t.shape)
# Out:
# Graph(num_nodes=3639, num_edges=25473,
#       ndata_schemes={}
#       edata_schemes={})
# X_t torch.Size([3639, 3003]) torch.float32
# C_t torch.Size([3639, 2])

# %%
# Cell 3  ──────────────────────────────────────────────────────────────
# ⚙️  hyper-params ------  (tweak as you like)
EMBED_DIM    = 256   # latent dimension per token (cell)
DEPTH        = 6     # number of transformer layers
NUM_HEADS    = 8

args = SimpleNamespace(
    num_heads=NUM_HEADS,
    num_out_heads=1,
    num_hidden=EMBED_DIM,
    num_layers=DEPTH,
    attn_drop=0.1,
    dropout=0.1,
    norm='layernorm',
    negative_slope=0.2,
    encoder='gat',
    decoder='mlp',
    mask_node_rate=0.3,
    mask_feature_rate=0.3,
    activation='prelu',
    loss_fn='sce',
    concat_hidden=False,
    num_features=G,
    latent_dim=EMBED_DIM,
    pe=None,
    drop_node_rate=0.0,
    objective='mask',
    standardscale=250,
    cat_pe=False,
    pe_aug=False,
    aggr='SAGE',
)

model = build_model(args)

device_pref = str(globals().get('device', 'auto')).lower()
force_cpu = device_pref == 'cpu'
device = torch.device('cpu')
if torch.cuda.is_available() and not force_cpu:
    try:
        cuda_device = torch.device('cuda')
        model = model.to(cuda_device)
        g = g.to(cuda_device)
        X_t = X_t.to(cuda_device)
        C_t = C_t.to(cuda_device)
        device = cuda_device
    except Exception as exc:
        print(f'⚠️ CUDA fallback → {exc}')
        model = model.to(device)
        g = g.to(device)
        X_t = X_t.to(device)
        C_t = C_t.to(device)
else:
    if device_pref == 'cuda' and not torch.cuda.is_available():
        print('⚠️ device="cuda" requested but unavailable; using CPU.')
    elif force_cpu:
        print('Using CPU because device="cpu" was requested.')
    else:
        print('⚠️ torch.cuda.is_available() returned False; using CPU.')
    model = model.to(device)
    g = g.to(device)
    X_t = X_t.to(device)
    C_t = C_t.to(device)


# stash node features for the masking objective
g.ndata['feat'] = X_t
g.ndata['raw'] = X_t
print(f'Encoder params: {sum(p.numel() for p in model.parameters())/1e6:.2f} M')
print(f'Using device: {device}')
# Out:
# ⚠️ CUDA fallback → [19:21:00] /opt/dgl/src/runtime/c_runtime_api.cc:88: Check failed: allow_missing: Device API gpu is not enabled. Please install the cuda version of dgl.
# Stack trace:
#   [bt] (0) /home/muscede2/anaconda3/envs/spaformer/lib/python3.10/site-packages/dgl/libdgl.so(dmlc::LogMessageFatal::~LogMessageFatal()+0x4f) [0x7f52e39a16ef]
#   [bt] (1) /home/muscede2/anaconda3/envs/spaformer/lib/python3.10/site-packages/dgl/libdgl.so(dgl::runtime::DeviceAPIManager::GetAPI(std::string, bool)+0x37c) [0x7f52e3c6f7dc]
#   [bt] (2) /home/muscede2/anaconda3/envs/spaformer/lib/python3.10/site-packages/dgl/libdgl.so(dgl::runtime::DeviceAPI::Get(DLContext, bool)+0x1f4) [0x7f52e3c69b44]
#   [bt] (3) /home/muscede2/anaconda3/envs/spaformer/lib/python3.10/site-packages/dgl/libdgl.so(dgl::runtime::NDArray::Empty(std::vector<long, std::allocator<long> >, DLDataType, DLContext)+0x15b) [0x7f52e3c8b24b]
# ...

# %%
# Cell 4  ─ Pre-train SpaFormer via masking ─
TRAIN_EPOCHS = 400
LR = 1e-3
WEIGHT_DECAY = 1e-5
CKPT_PATH = PP_DIR / 'spaformer_pretrained.pt'
RESUME = False  # set True to continue from an existing checkpoint

if RESUME and CKPT_PATH.exists():
    state = torch.load(CKPT_PATH, map_location=device)
    model.load_state_dict(state)
    print(f'Loaded existing checkpoint ← {CKPT_PATH}')
else:
    if CKPT_PATH.exists():
        CKPT_PATH.unlink()
        print(f'Removing old checkpoint at {CKPT_PATH} and restarting from scratch.')
    else:
        print('No existing SpaFormer checkpoint found; training from scratch.')

if TRAIN_EPOCHS > 0:
    optimizer = torch.optim.Adam(
        [
            {'params': model.enc_params, 'lr': LR},
            {'params': model.dec_params, 'lr': LR},
        ],
        weight_decay=WEIGHT_DECAY,
    )
    model.train()
    for epoch in range(1, TRAIN_EPOCHS + 1):
        optimizer.zero_grad()
        loss = model(g, X_t)
        loss.backward()
        optimizer.step()
        if epoch == 1 or epoch % 50 == 0:
            print(f'epoch {epoch:03d}/{TRAIN_EPOCHS}   loss {loss.item():.4f}')
    torch.save(model.state_dict(), CKPT_PATH)
    print('Saved checkpoint →', CKPT_PATH)
else:
    print('TRAIN_EPOCHS set to 0 — skipping optimisation step.')

model.eval()
with torch.no_grad():
    final_loss = model(g, X_t).item()
print(f'Final SpaFormer loss: {final_loss:.4f}')
# Out:
# Removing old checkpoint at Data/spaformer_prepared/spaformer_pretrained.pt and restarting from scratch.
# epoch 001/400   loss 0.4044
# epoch 050/400   loss 0.1350
# epoch 100/400   loss 0.1285
# epoch 150/400   loss 0.1267
# epoch 200/400   loss 0.1249
# epoch 250/400   loss 0.1267
# epoch 300/400   loss 0.1235
# epoch 350/400   loss 0.1231
# epoch 400/400   loss 0.1232
# Saved checkpoint → Data/spaformer_prepared/spaformer_pretrained.pt
# Final SpaFormer loss: 0.1212

# %%
# Cell X  ─ Nested Learning Fine-tuning (EM-style) ─
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from pathlib import Path

if not enable_nested_learning:
    print('Nested learning disabled; skipping.')
else:
    random.seed(random_seed)
    np.random.seed(random_seed)
    torch.manual_seed(random_seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(random_seed)

    def cluster_embeddings(
        Z_bank,
        method,
        knn_k,
        leiden_resolution,
        kmeans_K,
        dbscan_eps,
        dbscan_min_samples,
        random_state=0,
    ):
        method = str(method).lower()
        if method == 'leiden':
            import scanpy as sc
            import anndata as ad
            adata = ad.AnnData(X=Z_bank)
            sc.pp.neighbors(adata, n_neighbors=int(knn_k), use_rep='X', metric='cosine')
            sc.tl.leiden(adata, resolution=float(leiden_resolution), key_added='leiden')
            labels = adata.obs['leiden'].astype('category').cat.codes.to_numpy().astype(int)
            return labels
        if method == 'kmeans':
            from sklearn.cluster import KMeans
            km = KMeans(n_clusters=int(kmeans_K), random_state=random_state, n_init='auto')
            labels = km.fit_predict(Z_bank)
            return labels.astype(int)
        if method == 'dbscan':
            from sklearn.cluster import DBSCAN
            labels = DBSCAN(eps=float(dbscan_eps), min_samples=int(dbscan_min_samples)).fit_predict(Z_bank)
            return labels.astype(int)
        raise ValueError(f'Unknown cluster_method: {method}')

    def remap_labels(labels):
        labels = np.asarray(labels, dtype=int)
        valid_mask = labels != -1
        unique = np.unique(labels[valid_mask])
        mapping = {old: i for i, old in enumerate(unique)}
        remapped = np.full(labels.shape, -1, dtype=int)
        for old, new in mapping.items():
            remapped[labels == old] = new
        return remapped, int(len(unique))

    def compute_embeddings():
        model.eval()
        with torch.no_grad():
            z = model.embed(g, X_t)
        return z.detach().cpu().numpy()

    device = next(model.parameters()).device
    lr = LR if 'LR' in globals() else 1e-3
    weight_decay = WEIGHT_DECAY if 'WEIGHT_DECAY' in globals() else 1e-5

    edges_np_local = edges_np if 'edges_np' in globals() else np.load(PP_DIR / 'edges.npy')
    edges_t = torch.from_numpy(edges_np_local).long().to(device)
    edge_u = edges_t[0]
    edge_v = edges_t[1]

    Z_bank = compute_embeddings()
    y_prev = None
    metrics = []

    for it in range(1, outer_iters + 1):
        y_raw = cluster_embeddings(
            Z_bank,
            method=cluster_method,
            knn_k=knn_k,
            leiden_resolution=leiden_resolution,
            kmeans_K=kmeans_K,
            dbscan_eps=dbscan_eps,
            dbscan_min_samples=dbscan_min_samples,
            random_state=random_seed + it,
        )
        y_remap, K = remap_labels(y_raw)
        valid_mask = y_remap != -1
        valid_count = int(valid_mask.sum())
        if K == 0 or valid_count == 0:
            print(f'[Iter {it:02d}] No valid clusters found; skipping.')
            continue

        head = nn.Linear(EMBED_DIM, K).to(device)
        optimizer = torch.optim.Adam(
            [
                {'params': model.enc_params, 'lr': lr},
                {'params': model.dec_params, 'lr': lr},
                {'params': head.parameters(), 'lr': lr},
            ],
            weight_decay=weight_decay,
        )

        y_t_tensor = torch.from_numpy(y_remap[valid_mask]).long().to(device)
        valid_mask_t = torch.from_numpy(valid_mask).to(device)

        for epoch in range(1, outer_epochs_per_iter + 1):
            model.train(); head.train()
            optimizer.zero_grad()

            loss_mask = model(g, X_t)
            z = model.embed(g, X_t)

            loss_cluster = torch.tensor(0.0, device=device)
            if lambda_cluster > 0:
                logits = head(z[valid_mask_t])
                loss_cluster = F.cross_entropy(logits, y_t_tensor)

            loss_smooth = torch.tensor(0.0, device=device)
            if lambda_smooth > 0:
                if smoothness_mode == 'embedding':
                    diff = z[edge_u] - z[edge_v]
                    loss_smooth = diff.pow(2).sum(1).mean()
                elif smoothness_mode == 'kl_logits':
                    logits_all = head(z)
                    log_p = F.log_softmax(logits_all, dim=1)
                    q = F.softmax(logits_all, dim=1)
                    loss_smooth = (
                        F.kl_div(log_p[edge_u], q[edge_v], reduction='batchmean') +
                        F.kl_div(log_p[edge_v], q[edge_u], reduction='batchmean')
                    )
                else:
                    raise ValueError(f'Unknown smoothness_mode: {smoothness_mode}')

            loss_cons = torch.tensor(0.0, device=device)
            if lambda_cons > 0:
                z2 = model.embed(g, X_t)
                loss_cons = (z - z2).pow(2).sum(1).mean()

            loss = (
                lambda_mask * loss_mask +
                lambda_cluster * loss_cluster +
                lambda_smooth * loss_smooth +
                lambda_cons * loss_cons
            )
            loss.backward()
            optimizer.step()

        Z_bank = compute_embeddings()

        ari = None
        if y_prev is not None:
            mask_ari = (y_prev != -1) & (y_remap != -1)
            if mask_ari.sum() > 1:
                from sklearn.metrics import adjusted_rand_score
                ari = adjusted_rand_score(y_prev[mask_ari], y_remap[mask_ari])

        metrics.append({
            'iter': it,
            'clusters': K,
            'valid_nodes': valid_count,
            'ari_vs_prev': ari if ari is not None else np.nan,
        })
        print(f'[Iter {it:02d}] clusters={K} valid={valid_count} ari={ari}')
        y_prev = y_remap

    if y_prev is None:
        y_prev = np.zeros(Z_bank.shape[0], dtype=int)
        print('Nested loop produced no labels; defaulting to a single cluster.')

    labels_nested = y_prev.astype(int)
    latent_nested = Z_bank.astype(np.float32)

    np.save(PP_DIR / 'latent_nested.npy', latent_nested)
    np.save(PP_DIR / 'labels_nested.npy', labels_nested)
    torch.save(model.state_dict(), PP_DIR / 'spaformer_nested.pt')
    print('Saved nested outputs to spaformer_prepared/')

    # build hyperedge index (0-based, contiguous)
    valid_mask = labels_nested != -1
    unique = np.unique(labels_nested[valid_mask])
    mapping = {lab: i for i, lab in enumerate(unique)}
    labels_contig = np.full(labels_nested.shape, -1, dtype=int)
    for lab, new in mapping.items():
        labels_contig[labels_nested == lab] = new

    node_ids = []
    edge_ids = []
    for k in range(len(unique)):
        members = np.where(labels_contig == k)[0]
        if members.size == 0:
            continue
        node_ids.append(members.astype(np.int64))
        edge_ids.append(np.full(members.shape, k, dtype=np.int64))

    if node_ids:
        hyperedge_index_nested = np.vstack([
            np.concatenate(node_ids),
            np.concatenate(edge_ids),
        ])
    else:
        hyperedge_index_nested = np.zeros((2, 0), dtype=np.int64)

    np.save(Path('Data') / 'hyperedge_index_nested.npy', hyperedge_index_nested)
    print('Saved nested hyperedge index → Data/hyperedge_index_nested.npy')

    if metrics:
        import pandas as pd
        df = pd.DataFrame(metrics)
        df.to_csv(PP_DIR / 'nested_metrics.csv', index=False)
        print('Saved metrics →', PP_DIR / 'nested_metrics.csv')
# Out:
# [Iter 01] clusters=7 valid=3639 ari=None
# [Iter 02] clusters=7 valid=3639 ari=0.4711880884517517
# [Iter 03] clusters=7 valid=3639 ari=0.7034724639776879
# [Iter 04] clusters=7 valid=3639 ari=0.625692657531287
# [Iter 05] clusters=7 valid=3639 ari=0.6015390089309823
# [Iter 06] clusters=7 valid=3639 ari=0.6644251739657122
# [Iter 07] clusters=7 valid=3639 ari=0.7668970209213677
# [Iter 08] clusters=7 valid=3639 ari=0.7984573797102154
# [Iter 09] clusters=7 valid=3639 ari=0.7423967858300016
# [Iter 10] clusters=7 valid=3639 ari=0.749574754151054
# [Iter 11] clusters=7 valid=3639 ari=0.7431413868217558
# [Iter 12] clusters=7 valid=3639 ari=0.9006450662356698
# [Iter 13] clusters=7 valid=3639 ari=0.8358730038497808
# [Iter 14] clusters=7 valid=3639 ari=0.47580862457171785
# [Iter 15] clusters=7 valid=3639 ari=0.7595341118270771
# [Iter 16] clusters=7 valid=3639 ari=0.8516218816471401
# [Iter 17] clusters=7 valid=3639 ari=0.738990186949562
# ...

# %%
# Cell 5  ──────────────────────────────────────────────────────────────
with torch.no_grad():                         # inference
    latent_t = model.embed(g, X_t)             # (N, EMBED_DIM)

print('latent_t:', latent_t.shape)
# Out:
# latent_t: torch.Size([3639, 256])

# %%
# Cell 6  ──────────────────────────────────────────────────────────────
latent_np = latent_t.cpu().numpy()
LATENT_PATH = PP_DIR / 'latent.npy'
np.save(LATENT_PATH, latent_np)
print('Saved →', LATENT_PATH)

# (optional) small AnnData wrapper for Scanpy/UMAP downstream
import scanpy as sc, anndata as ad
obs_index = [f'cell_{i}' for i in range(N)]
var_index = [f'z{i}' for i in range(latent_np.shape[1])]
adata_latent = ad.AnnData(
        X            = latent_np,
        obs          = pd.DataFrame(index=obs_index),
        var          = pd.DataFrame(index=var_index),
    )
adata_latent.obsm['spatial'] = C_np          # keep coords
print('AnnData object ready; run Cell 6 for neighbours/Leiden + disk save')
# Out:
# Saved → Data/spaformer_prepared/latent.npy
# AnnData object ready; run Cell 6 for neighbours/Leiden + disk save

# %%
# Cell 6  ─ Contrastive refinement on SpaFormer embedding ─
import torch, torch.nn as nn, torch.nn.functional as F
from tqdm.auto import trange

device_refine = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

latent_raw = latent_np.astype('float32')
np.save(PP_DIR / 'latent_raw.npy', latent_raw)

edges_np = np.load(PP_DIR / 'edges.npy')
num_nodes = latent_raw.shape[0]

adj_binary = np.zeros((num_nodes, num_nodes), dtype=np.float32)
adj_binary[edges_np[0], edges_np[1]] = 1.0
adj_binary[edges_np[1], edges_np[0]] = 1.0
adj_binary[np.arange(num_nodes), np.arange(num_nodes)] = 1.0

deg = adj_binary.sum(axis=1)
deg_safe = np.maximum(deg, 1.0).astype(np.float32)
deg_inv_sqrt = np.power(deg_safe, -0.5, dtype=np.float32)
adj_norm = (deg_inv_sqrt[:, None] * adj_binary) * deg_inv_sqrt[None, :]

adj_norm_t = torch.from_numpy(adj_norm).to(device_refine)
mask_t = torch.from_numpy(adj_binary).to(device_refine)
features_t = torch.from_numpy(latent_raw).to(device_refine)

label_csl = torch.tensor(
    np.repeat([[1.0, 0.0]], num_nodes, axis=0),
    dtype=torch.float32,
    device=device_refine,
)

class AvgReadout(nn.Module):
    def __init__(self, mask):
        super().__init__()
        self.register_buffer('mask', mask)
    def forward(self, emb):
        vsum = self.mask @ emb
        denom = self.mask.sum(dim=1, keepdim=True).clamp_min(1.0)
        return F.normalize(vsum / denom, p=2, dim=1)

class ContrastiveRefiner(nn.Module):
    def __init__(self, in_dim, hidden_dim, mask):
        super().__init__()
        self.w_enc = nn.Parameter(torch.empty(in_dim, hidden_dim))
        self.w_dec = nn.Parameter(torch.empty(hidden_dim, in_dim))
        nn.init.xavier_uniform_(self.w_enc)
        nn.init.xavier_uniform_(self.w_dec)
        self.readout = AvgReadout(mask)
        self.disc = nn.Bilinear(hidden_dim, hidden_dim, 1)
        nn.init.xavier_uniform_(self.disc.weight)
        if self.disc.bias is not None:
            nn.init.zeros_(self.disc.bias)
        self.act = nn.PReLU()
    def forward(self, feat, feat_perm, adj_norm):
        z = adj_norm @ (feat @ self.w_enc)
        emb = self.act(z)
        recon = adj_norm @ (emb @ self.w_dec)
        z_perm = adj_norm @ (feat_perm @ self.w_enc)
        emb_perm = self.act(z_perm)
        summary = self.readout(emb)
        summary_perm = self.readout(emb_perm)
        logits_pos = torch.cat(
            (self.disc(emb, summary), self.disc(emb_perm, summary)),
            dim=1,
        )
        logits_neg = torch.cat(
            (self.disc(emb_perm, summary_perm), self.disc(emb, summary_perm)),
            dim=1,
        )
        return emb, recon, logits_pos, logits_neg

refiner = ContrastiveRefiner(features_t.shape[1], features_t.shape[1], mask_t).to(device_refine)
optim = torch.optim.Adam(refiner.parameters(), lr=1e-3, weight_decay=1e-5)
criterion = nn.BCEWithLogitsLoss()

alpha = 1.0
beta = 0.5
epochs_refine = 300

for epoch in trange(epochs_refine, desc='Contrastive refine', leave=False):
    permuted = features_t[torch.randperm(num_nodes)]
    emb, recon, logits_pos, logits_neg = refiner(features_t, permuted, adj_norm_t)
    loss_recon = F.mse_loss(recon, features_t)
    loss_contrast = criterion(logits_pos, label_csl) + criterion(logits_neg, label_csl)
    loss = alpha * loss_recon + beta * loss_contrast
    optim.zero_grad()
    loss.backward()
    optim.step()
    if (epoch + 1) % 50 == 0:
        print(f'epoch {epoch+1:03d}/{epochs_refine} loss {loss.item():.4f}')

with torch.no_grad():
    refined_emb, _, _, _ = refiner(features_t, features_t, adj_norm_t)
    refined_emb = F.normalize(refined_emb, p=2, dim=1)

refined_np = refined_emb.cpu().numpy().astype('float32')
np.save(PP_DIR / 'latent_refined.npy', refined_np)
adata_latent.X = refined_np
latent_np = refined_np
print('Saved refined embedding →', PP_DIR / 'latent_refined.npy')
# Out:
# Contrastive refine:  18%|█▊        | 53/300 [00:04<00:22, 11.10it/s]
# epoch 050/300 loss 0.6945
# Contrastive refine:  34%|███▍      | 103/300 [00:09<00:17, 11.02it/s]
# epoch 100/300 loss 0.6936
# Contrastive refine:  51%|█████     | 153/300 [00:13<00:13, 11.08it/s]
# epoch 150/300 loss 0.6935
# Contrastive refine:  68%|██████▊   | 203/300 [00:18<00:08, 11.04it/s]
# epoch 200/300 loss 0.6935
# Contrastive refine:  84%|████████▍ | 253/300 [00:22<00:04, 11.01it/s]
# epoch 250/300 loss 0.6934
# epoch 300/300 loss 0.6933
# Saved refined embedding → Data/spaformer_prepared/latent_refined.npy

# %%
# Cell 7  ─ Enforce spatial smoothness in Leiden ─
import scanpy as sc
import numpy as np

LEIDEN_TARGET = 7
RESOLUTION_MIN = 0.05
RESOLUTION_MAX = 0.8
RESOLUTION_STEPS = 20
REFINE_STEPS = 6
COORD_WEIGHT = 0.10
SMOOTH_ITER = 2
ORDER_AXIS = 1  # 0 = x, 1 = y
EPS = 1e-6

latent = adata_latent.X
coords = adata_latent.obsm['spatial']
edges_np = np.load(PP_DIR / 'edges.npy')
num_nodes = latent.shape[0]

latent_mean = latent.mean(axis=0, keepdims=True)
latent_std = latent.std(axis=0, keepdims=True) + EPS
latent_z = (latent - latent_mean) / latent_std

coords_mean = coords.mean(axis=0, keepdims=True)
coords_std = coords.std(axis=0, keepdims=True) + EPS
coords_z = (coords - coords_mean) / coords_std

latent_spatial = np.concatenate([latent_z, COORD_WEIGHT * coords_z], axis=1).astype('float32')
adata_latent.obsm['latent_spatial'] = latent_spatial

adj_binary = np.zeros((num_nodes, num_nodes), dtype=bool)
adj_binary[edges_np[0], edges_np[1]] = True
adj_binary[edges_np[1], edges_np[0]] = True
adj_binary[np.arange(num_nodes), np.arange(num_nodes)] = True
neighbor_lists = [np.flatnonzero(adj_binary[i]) for i in range(num_nodes)]

sc.pp.neighbors(adata_latent, n_neighbors=15, use_rep='latent_spatial')
sc.tl.umap(adata_latent)

def run_leiden(resolution: float):
    res = float(resolution)
    key = f'leiden_{res:.5f}'
    if key not in adata_latent.obs:
        sc.tl.leiden(adata_latent, resolution=res, key_added=key)
    cats = adata_latent.obs[key].astype('category')
    return key, cats.cat.categories.size

records = []
best = None
res_grid = np.linspace(RESOLUTION_MIN, RESOLUTION_MAX, RESOLUTION_STEPS)
for res in res_grid:
    key, n_clusters = run_leiden(res)
    records.append((float(res), int(n_clusters), key))
    diff = abs(n_clusters - LEIDEN_TARGET)
    if best is None or diff < best[2]:
        best = [float(res), key, diff, int(n_clusters)]
    if n_clusters == LEIDEN_TARGET:
        break
else:
    bracket = None
    for (r1, c1, k1), (r2, c2, k2) in zip(records[:-1], records[1:]):
        if (c1 - LEIDEN_TARGET) * (c2 - LEIDEN_TARGET) <= 0 and c1 != c2:
            if r1 > r2:
                r1, r2, k1, k2 = r2, r1, k2, k1
                c1, c2 = c2, c1
            bracket = (r1, c1, k1, r2, c2, k2)
            break
    if bracket is not None:
        low_res, low_clusters, low_key, high_res, high_clusters, high_key = bracket
        for _ in range(REFINE_STEPS):
            if abs(high_res - low_res) < 1e-4:
                break
            mid = 0.5 * (low_res + high_res)
            key, n_clusters = run_leiden(mid)
            records.append((float(mid), int(n_clusters), key))
            diff = abs(n_clusters - LEIDEN_TARGET)
            if diff < best[2]:
                best = [float(mid), key, diff, int(n_clusters)]
            if n_clusters == LEIDEN_TARGET:
                best = [float(mid), key, diff, int(n_clusters)]
                break
            if n_clusters < LEIDEN_TARGET:
                low_res, low_clusters, low_key = mid, n_clusters, key
            else:
                high_res, high_clusters, high_key = mid, n_clusters, key

records_sorted = sorted({(round(res, 5), clusters) for res, clusters, _ in records})
print('Leiden trials (resolution → clusters):', records_sorted)
print(f'Chosen resolution {best[0]:.5f} → {best[3]} clusters')

adata_latent.obs['leiden'] = adata_latent.obs[best[1]].astype('category')
labels = adata_latent.obs['leiden'].cat.codes.to_numpy()

if SMOOTH_ITER > 0:
    for _ in range(SMOOTH_ITER):
        smoothed = labels.copy()
        for i, neigh in enumerate(neighbor_lists):
            votes = np.bincount(labels[neigh], minlength=labels.max()+1)
            smoothed[i] = votes.argmax()
        labels = smoothed

unique_labels = np.unique(labels)
axis_vals = coords[:, ORDER_AXIS]
order = sorted(unique_labels, key=lambda lab: axis_vals[labels == lab].mean())
mapping = {lab: i for i, lab in enumerate(order)}
ordered_labels = np.array([mapping[lab] for lab in labels], dtype=int)

adata_latent.obs['leiden'] = ordered_labels.astype(str)
np.save(PP_DIR / 'leiden_labels.npy', ordered_labels)
print('Saved Leiden labels →', PP_DIR / 'leiden_labels.npy')

adata_latent.write(PP_DIR / 'latent.h5ad')
print('Saved AnnData with Leiden labels →', PP_DIR / 'latent.h5ad')

sc.pl.umap(
    adata_latent,
    color=['leiden'],
    size=20
)
# Out:
# ... storing 'leiden' as categorical
# Leiden trials (resolution → clusters): [(0.05, 6), (0.08947, 6), (0.09934, 6), (0.10428, 7), (0.10921, 8), (0.12895, 8), (0.16842, 9), (0.20789, 9), (0.24737, 12), (0.28684, 14), (0.32632, 14), (0.36579, 15), (0.40526, 15), (0.44474, 15), (0.48421, 16), (0.52368, 18), (0.56316, 18), (0.60263, 16), (0.64211, 18), (0.68158, 17), (0.72105, 20), (0.76053, 20), (0.8, 22)]
# Chosen resolution 0.10428 → 7 clusters
# Saved Leiden labels → Data/spaformer_prepared/leiden_labels.npy
# Saved AnnData with Leiden labels → Data/spaformer_prepared/latent.h5ad

# %%
# Cell 8  ─ GraphST-style clustering & spatial refinement ─
import numpy as np
import scanpy as sc
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors

TARGET_CLUSTERS = 7
PCA_COMPONENTS = 20
NEIGHBORS_PCA = 50
REFINE_K = 50
REFINE_STEPS = 2
RESOLUTION_START = 0.1
RESOLUTION_END = 3.0
RESOLUTION_STEP = 0.01
ORDER_AXIS = 1  # 0=x, 1=y

latent = adata_latent.X
coords = adata_latent.obsm['spatial']

pca = PCA(n_components=PCA_COMPONENTS, random_state=42)
embedding = pca.fit_transform(latent)
adata_latent.obsm['latent_pca'] = embedding.astype('float32')

sc.pp.neighbors(adata_latent, n_neighbors=NEIGHBORS_PCA, use_rep='latent_pca')

print('Searching resolution...')
best_res = None
best_diff = None
best_n = None
resolutions = np.arange(RESOLUTION_START, RESOLUTION_END, RESOLUTION_STEP)[::-1]
for res in resolutions:
    sc.tl.leiden(adata_latent, random_state=0, resolution=float(res))
    n_cluster = adata_latent.obs['leiden'].nunique()
    print(f'resolution={res:.2f}, clusters={n_cluster}')
    diff = abs(n_cluster - TARGET_CLUSTERS)
    if best_diff is None or diff < best_diff:
        best_res = float(res)
        best_diff = diff
        best_n = int(n_cluster)
    if n_cluster == TARGET_CLUSTERS:
        break
if best_res is None:
    raise ValueError('Leiden search failed; try expanding the resolution range.')
# ensure labels correspond to chosen resolution
sc.tl.leiden(adata_latent, random_state=0, resolution=float(best_res))
if best_n != TARGET_CLUSTERS:
    print(f'No exact match; using closest resolution {best_res:.2f} with {best_n} clusters.')
else:
    print(f'Chosen resolution: {best_res:.2f}')

labels = adata_latent.obs['leiden'].astype(int).to_numpy()
nbrs = NearestNeighbors(n_neighbors=REFINE_K + 1, metric='euclidean').fit(coords)
_, neigh_idx = nbrs.kneighbors(coords)

for _ in range(REFINE_STEPS):
    smoothed = labels.copy()
    for i, neigh in enumerate(neigh_idx):
        neigh = neigh[1:]
        votes = np.bincount(labels[neigh], minlength=labels.max() + 1)
        smoothed[i] = votes.argmax()
    labels = smoothed

unique_labels = np.unique(labels)
axis_vals = coords[:, ORDER_AXIS]
order = sorted(unique_labels, key=lambda lab: axis_vals[labels == lab].mean())
mapping = {lab: i for i, lab in enumerate(order)}
ordered_labels = np.array([mapping[lab] for lab in labels], dtype=int)

adata_latent.obs['reference_clusters'] = ordered_labels.astype(str)
np.save(PP_DIR / 'leiden_labels.npy', ordered_labels)
print('Saved Leiden labels →', PP_DIR / 'leiden_labels.npy')

adata_latent.write(PP_DIR / 'latent.h5ad')
print('Saved AnnData with refined clusters →', PP_DIR / 'latent.h5ad')

sc.pl.umap(
    adata_latent,
    color=['reference_clusters'],
    size=20
)
# Out:
# Searching resolution...
# resolution=2.99, clusters=41
# resolution=2.98, clusters=42
# resolution=2.97, clusters=42
# resolution=2.96, clusters=42
# resolution=2.95, clusters=42
# resolution=2.94, clusters=42
# resolution=2.93, clusters=42
# resolution=2.92, clusters=42
# resolution=2.91, clusters=42
# resolution=2.90, clusters=43
# resolution=2.89, clusters=43
# resolution=2.88, clusters=41
# resolution=2.87, clusters=40
# resolution=2.86, clusters=40
# resolution=2.85, clusters=41
# resolution=2.84, clusters=40
# resolution=2.83, clusters=40
# resolution=2.82, clusters=39
# resolution=2.81, clusters=40
# resolution=2.80, clusters=40
# resolution=2.79, clusters=41
# resolution=2.78, clusters=43
# resolution=2.77, clusters=41
# resolution=2.76, clusters=39
# resolution=2.75, clusters=39
# resolution=2.74, clusters=39
# resolution=2.73, clusters=37
# resolution=2.72, clusters=37
# resolution=2.71, clusters=37
# resolution=2.70, clusters=37
# resolution=2.69, clusters=37
# ...
